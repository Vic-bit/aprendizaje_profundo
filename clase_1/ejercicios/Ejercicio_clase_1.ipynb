# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Forward:
#
# $ Z^{(1)}_{i,1} = W^{(1)}_{1,1} * X_{i,1} + W^{(1)}_{1,2} * X_{i,2} + b^{(1)}_1 $
#
# $ Z^{(1)}_{i,2} = W^{(1)}_{2,1} * X_{i,1} + W^{(1)}_{2,2} * X_{i,2} + b^{(1)}_2 $
#
# $ a^{(1)}_{i,1} = σ(Z^{(1)}_{i,1}) $
#
# $ a^{(1)}_{i,2} = σ(Z^{(1)}_{i,2}) $
#
# $ z^{(2)} = w^{(2)} * x^{(2)} + b^{(2)} $
#
# $ Z^{(2)}_{i,1} = W^{(2)}_{1,1} * a^{(1)}_{i,1} + W^{(2)}_{1,2} * a^{(1)}_{i,2} + b^{(2)}_1 $
#
# $ a^{(2)}_{i,1} = σ(Z^{(2)})_{i,1} $
#
# $ y_i = a^{(2)}_{i,1} = Z^{(2)}_{i,1} $
#
# $ Lw = (y_i - \hat{y_i})^2 $

# %% [markdown]
# Backguard Derivadas parciales:
#
# Capa 2, neurona 1, peso W1:
#
# $
# \frac{\partial{L}}{\partial{W^{(2)}_{1,1}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{W^{(2)}_{1,1}}} =
# -2 * (y_i - \hat{y}_i) * a^{(1)}_{i,1}
# $
#
# Capa 2, neurona 1, peso W2:
#
# $
# \frac{\partial{L}}{\partial{W^{(2)}_{1,2}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{W^{(2)}_{1,2}}} =
# -2 * (y_i - \hat{y}_i) * a^{(1)}_{i,2}
# $
#
# Capa 2, neurona 1, peso b:
#
# $
# \frac{\partial{L}}{\partial{b^{(2)}_{1}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{b^{(2)}_{1}}} =
# -2 * (y_i - \hat{y}_i) * W^{(2)}_{1,1}
# $
#
# Capa 1, neurona 1, peso W1:
#
# $
# \frac{\partial{L}}{\partial{W^{(1)}_{1,1}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{a^{(1)}_{i,1}}} *
# \frac{\partial{a^{(1)}_{i,1}}}{\partial{Z^{(1)}_{i,1}}} *
# \frac{\partial{Z^{(1)}_{i,1}}}{\partial{W^{(1)}_{1,1}}} =
# -2 * (y_i - \hat{y}_i) * W^{(1)}_{1,1} *  σ(Z^{(1)}_{i,1}) * (1 -  σ(Z^{(1)}_{i,1})) * X_{i,1}
# $
#
#
# Capa 1, neurona 1, peso W2:
#
# $
# \frac{\partial{L}}{\partial{W^{(1)}_{1,2}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{a^{(1)}_{i,1}}} *
# \frac{\partial{a^{(1)}_{i,1}}}{\partial{Z^{(1)}_{i,1}}} *
# \frac{\partial{Z^{(1)}_{i,1}}}{\partial{W^{(1)}_{1,1}}} =
# -2 * (y_i - \hat{y}_i) * W^{(1)}_{1,2} *  σ(Z^{(1)}_{i,1}) * (1 -  σ(Z^{(1)}_{i,1})) * X_{i,2}
# $
#
# Capa 1, neurona 1, peso b1:
#
# $
# \frac{\partial{L}}{\partial{b^{(1)}_{1}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{a^{(1)}_{i,1}}} *
# \frac{\partial{a^{(1)}_{i,1}}}{\partial{Z^{(1)}_{i,1}}} *
# \frac{\partial{Z^{(1)}_{i,1}}}{\partial{b^{(1)}_{1}}} =
# -2 * (y_i - \hat{y}_i) * W^{(1)}_{1,2} *  σ(Z^{(1)}_{i,1}) * (1 -  σ(Z^{(1)}_{i,1}))
# $
#
# Capa 1, neurona 2, peso W1:
#
# $
# \frac{\partial{L}}{\partial{W^{(1)}_{1,1}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{a^{(1)}_{i,2}}} *
# \frac{\partial{a^{(1)}_{i,1}}}{\partial{Z^{(1)}_{i,2}}} *
# \frac{\partial{Z^{(1)}_{i,2}}}{\partial{W^{(1)}_{2,1}}} =
# -2 * (y_i - \hat{y}_i) * W^{(1)}_{1,2} *  σ(Z^{(1)}_{i,2}) * (1 -  σ(Z^{(1)}_{i,2})) * X_{i,1}
# $
#
# Capa 1, neurona 2, peso W2:
#
# $
# \frac{\partial{L}}{\partial{W^{(1)}_{1,2}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{a^{(1)}_{i,2}}} *
# \frac{\partial{a^{(1)}_{i,1}}}{\partial{Z^{(1)}_{i,2}}} *
# \frac{\partial{Z^{(1)}_{i,2}}}{\partial{W^{(1)}_{2,2}}} =
# -2 * (y_i - \hat{y}_i) * W^{(1)}_{1,2} *  σ(Z^{(1)}_{i,2}) * (1 -  σ(Z^{(1)}_{i,2})) * X_{i,2}
# $
#
# Capa 1, neurona 2, peso b2:
#
# $
# \frac{\partial{L}}{\partial{b^{(1)}_{1}}} =
# \frac{\partial{L}}{\partial{\hat{y}_i}} *
# \frac{\partial{\hat{y}_i}}{\partial{a^{(1)}_{i,2}}} *
# \frac{\partial{a^{(1)}_{i,1}}}{\partial{Z^{(1)}_{i,2}}} *
# \frac{\partial{Z^{(1)}_{i,2}}}{\partial{b^{(1)}_{2}}} =
# -2 * (y_i - \hat{y}_i) * W^{(1)}_{1,2} *  σ(Z^{(1)}_{i,2}) * (1 -  σ(Z^{(1)}_{i,2}))
# $
